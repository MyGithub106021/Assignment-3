# %%
# !pip install selenium

# %%
import selenium
import pandas as pd  
from selenium import webdriver
from time import sleep
import time

# %%
driver = webdriver.Chrome("chromedriver")
url='https://www.amazon.in/'
driver.get(url)

# %%
input_search=driver.find_element_by_xpath('//input[@id="twotabsearchtextbox"]')
input_search
# Out:
# C:\Users\IFATH FATIMA\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:483: UserWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   warnings.warn("find_element_by_* commands are deprecated. Please use find_element() instead")
# <selenium.webdriver.remote.webelement.WebElement (session="85ddb02aca2953afd6169a11affc0740", element="3bc0f3eb-7765-4bf0-a152-2acc6ccc4f17")>

# %%
input_search.send_keys("handbags")

# %%
click_button=driver.find_element_by_xpath('//span[@id="nav-search-submit-text"]')
click_button.click()

# %%
products=[]
for i in range(1, 4, 1):
    print('scraping_page',i+1)
    product=driver.find_elements_by_xpath('//span[@class="a-size-base-plus a-color-base a-text-normal"]')
    for i in product:
        products.append(i.text)
        products
        
        sleep(1)
# Out:
# scraping_page 2
# C:\Users\IFATH FATIMA\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:502: UserWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   warnings.warn("find_elements_by_* commands are deprecated. Please use find_elements() instead")
# scraping_page 3
# scraping_page 4

# %%
len(products)
# Out:
# 201

# %%
products
# Out:
# ["Ushawu Dome Satchel Women's Handbag",
#  'Pavo Women’s Tote Bag',
#  "Betula Women's Tote Bag",
#  "Women's PU Leather Handbag Combo (4-teddy-pink)",
#  "Women's Catlin Handbag (Maroon) (FSB-1033)",
#  "Women's Handbag (Set of 4) (4L-bib-Bpink_Pink)",
#  "Women's Handbag (FRB-315_Red)",
#  "Women's Handbag (ASN-135_Purple)",
#  "Speed X Fashion Women's Handbag",
#  "Ushawu Dome Satchel Women's Handbag",
#  "Women's Tote Bag",
#  "Women's Zara Handbag (Tan) (FSB-1051)",
#  "Women's Handbag (Green)",
#  "Women's Handbag (FRB-321_Brown)",
#  "Women's Westside Handbag (Grey) (FSB-1237)",
#  "Women's PU Leather Handbag Combo (4-teddy-pink)",
#  "Women's Handbag (FRB-312_Black)",
#  "Women's Handbag (Set of 4, Grey)",
#  "Women's Handbag (HDBG-BLACK-03_Black)",
#  "women's Handbag combo Black (set of 5)",
#  "Autumn-Winter'20 womens Handbag",
#  'Handbag (Navy)',
#  'Handbag',
#  '',
#  '',
#  '',
#  '',
#  "Horse Women's Handbag",
#  'Extra Large Malnov Women’s Tote Bag',
# ...

# %%
brand=[]
for i in range(1, 4, 1):
    print('scraping_page',i+1)
    brands=driver.find_elements_by_xpath('//h5[@class="s-line-clamp-1"]')
    for i in brands:
        brand.append(i.text)
        brand
        
        sleep(1)
# Out:
# scraping_page 2
# scraping_page 3
# scraping_page 4

# %%
len(brand)
# Out:
# 201

# %%
brand
# Out:
# ['Lavie',
#  'Lavie',
#  'Lavie',
#  'Lavie',
#  'Fostelo',
#  'Mammon',
#  'Fristo',
#  'Aisna',
#  'SXF SPEED X FASHION',
#  'Star Dust',
#  'Fostelo',
#  'Fristo',
#  'Mammon',
#  'Fristo',
#  'Fristo',
#  'WOMEN MARKS',
#  'Fargo',
#  'Mammon',
#  'JSPM',
#  'Shining Star',
#  'Amazon Brand - Symbol',
#  'Amazon Brand - Symbol',
#  'Amazon Brand - Eden & Ivy',
#  '',
#  '',
#  '',
#  '',
#  'Lavie',
#  'CAPRESE',
#  'Mammon',
#  'Mammon',
#  'Lavie',
#  'Envias',
#  'Mammon',
#  'Lavie',
#  'Fiesto Fashion',
#  'Mammon',
#  'Envias',
#  'Amazon Brand - Eden & Ivy',
#  'Fargo',
#  'Al Jazeera',
#  'Fristo',
#  'Fristo',
#  'Baggit',
#  'Care4u',
#  'MARK & KEITH',
#  'Fristo',
#  'Envias',
#  'Baggit',
#  'Aisna',
#  'Fostelo',
#  'Fostelo',
#  'Bellina',
#  'Fostelo',
#  'Flavia',
#  'Fargo',
#  'WOMEN MARKS',
#  'Generic',
#  'Baggit',
#  'Aisna',
#  'Fostelo',
#  'Baggit',
#  'Bellina',
#  'Mammon',
#  'Mammon',
#  'Mammon',
#  'ADISA',
#  'Lavie',
#  'Lavie',
#  'Lavie',
# ...

# %%
price=[]
for i in range(1, 4, 1):
    print('scraping_page',i+1)
    price_tag=driver.find_elements_by_xpath('//span[@class="a-price-whole"]')
    for i in price_tag:
        price.append(i.text)
        price
        
        sleep(1)
# Out:
# scraping_page 2
# scraping_page 3
# scraping_page 4

# %%
len(price)
# Out:
# 198

# %%
price
# Out:
# ['875',
#  '4,499',
#  '1,199',
#  '1,462',
#  '569',
#  '689',
#  '520',
#  '549',
#  '594',
#  '389',
#  '562',
#  '520',
#  '649',
#  '520',
#  '520',
#  '1,098',
#  '542',
#  '699',
#  '367',
#  '699',
#  '611',
#  '713',
#  '679',
#  '',
#  '',
#  '',
#  '',
#  '875',
#  '1,735',
#  '499',
#  '699',
#  '875',
#  '337',
#  '699',
#  '875',
#  '649',
#  '379',
#  '689',
#  '679',
#  '649',
#  '596',
#  '629',
#  '629',
#  '1,156',
#  '659',
#  '949',
#  '629',
#  '347',
#  '1,066',
#  '508',
#  '645',
#  '562',
#  '349',
#  '645',
#  '779',
#  '560',
#  '699',
#  '499',
#  '933',
#  '615',
#  '645',
#  '389',
#  '649',
#  '689',
#  '699',
#  '749',
#  '875',
#  '4,499',
#  '1,199',
#  '1,462',
#  '569',
#  '689',
#  '520',
#  '549',
#  '594',
#  '389',
#  '562',
#  '520',
#  '649',
#  '520',
#  '520',
#  '1,098',
#  '542',
#  '699',
#  '367',
#  '699',
#  '611',
#  '713',
#  '679',
#  '',
#  '',
#  '',
#  '',
#  '875',
#  '1,735',
#  '499',
#  '699',
#  '875',
#  '337',
#  '699',
# ...

# %%
driver.get("https://www.amazon.in/s?k=handbags&ref=nb_sb_noss")

# %%
urls=[]
for i in range(1, 4, 1):
    url=driver.find_elements_by_xpath('//a[@class="a-link-normal a-text-normal"]')
    for i in url:
        urls.append(i.get_attribute("href"))
    urls
    sleep(1)

# %%
urls
# Out:
# ['https://www.amazon.in/gp/slredirect/picassoRedirect.html/ref=pa_sp_atf_aps_sr_pg1_1?ie=UTF8&adId=A01561592HGAX0ZBK78DL&url=%2FLavie-Ushawu-Womens-Satchel-Mint%2Fdp%2FB07T9GB7RN%2Fref%3Dsr_1_1_sspa%3Fdchild%3D1%26keywords%3Dhandbags%26qid%3D1632150347%26sr%3D8-1-spons%26psc%3D1&qualifier=1632150347&id=6374089565188910&widgetName=sp_atf',
#  'https://www.amazon.in/gp/slredirect/picassoRedirect.html/ref=pa_sp_atf_aps_sr_pg1_1?ie=UTF8&adId=A0162223228TVQJUCJ2U3&url=%2FLavie-Spring-Summer-Womens-Tote%2Fdp%2FB0814PH19W%2Fref%3Dsr_1_2_sspa%3Fdchild%3D1%26keywords%3Dhandbags%26qid%3D1632150347%26sr%3D8-2-spons%26psc%3D1&qualifier=1632150347&id=6374089565188910&widgetName=sp_atf',
# ...

# %%
len(urls)
# Out:
# 201

# %%
ratings=[]
for i in urls[:201]:
    driver.get(i)
    time.sleep(1)
    
    try:
        ratings_tags=driver.find_element_by_xpath('//span[@class="a-size-base a-nowrap"]')
        ratings.append(ratings_tags.text)
    except:
        ratings.append('-')
        sleep(1)

# %%
ratings
# Out:
# ['4 out of 5',
#  '4.1 out of 5',
#  '4.1 out of 5',
#  '3.5 out of 5',
#  '4.1 out of 5',
#  '3.8 out of 5',
#  '4.1 out of 5',
#  '4.1 out of 5',
#  '4 out of 5',
#  '4 out of 5',
#  '3.8 out of 5',
#  '4 out of 5',
#  '4.1 out of 5',
#  '4 out of 5',
#  '4.2 out of 5',
#  '3.5 out of 5',
#  '4 out of 5',
#  '3.4 out of 5',
#  '3.9 out of 5',
#  '2.3 out of 5',
#  '4.2 out of 5',
#  '4.5 out of 5',
#  '4.3 out of 5',
#  '4.4 out of 5',
#  '4.3 out of 5',
#  '4.3 out of 5',
#  '4.3 out of 5',
#  '4.2 out of 5',
#  '4.2 out of 5',
#  '4.2 out of 5',
#  '4.2 out of 5',
#  '4.4 out of 5',
#  '3.5 out of 5',
#  '4.2 out of 5',
#  '3.4 out of 5',
#  '3.8 out of 5',
#  '3.9 out of 5',
#  '3.6 out of 5',
#  '3.4 out of 5',
#  '4.3 out of 5',
#  '3.8 out of 5',
#  '-',
#  '4.1 out of 5',
#  '4 out of 5',
#  '3.8 out of 5',
#  '3.4 out of 5',
#  '3.7 out of 5',
#  '3.7 out of 5',
#  '3.9 out of 5',
#  '3.9 out of 5',
#  '3.9 out of 5',
#  '3.6 out of 5',
#  '4.2 out of 5',
# ...

# %%
len(ratings)
# Out:
# 201

# %%
number_of_ratings=[]
for i in urls[:201]:
    driver.get(i)
    time.sleep(1)
    
    try:
        number_tags=driver.find_element_by_xpath('//div[@data-hook="total-review-count"]')
        number_of_ratings.append(number_tags.text)
    except:
        number_of_ratings.append('-')
        sleep(1)

# %%
number_of_ratings
# Out:
# ['1,352 global ratings',
#  '1,412 global ratings',
#  '5,585 global ratings',
#  '2,072 global ratings',
#  '4,790 global ratings',
#  '2,780 global ratings',
#  '2,865 global ratings',
#  '1,567 global ratings',
#  '2,885 global ratings',
#  '1,352 global ratings',
#  '5,283 global ratings',
#  '1,122 global ratings',
#  '1,295 global ratings',
#  '1,208 global ratings',
#  '1,755 global ratings',
#  '2,072 global ratings',
#  '1,015 global ratings',
#  '1,259 global ratings',
#  '159 global ratings',
#  '6 global ratings',
#  '37 global ratings',
#  '8 global ratings',
#  '422 global ratings',
#  '48 global ratings',
#  '151 global ratings',
#  '56 global ratings',
#  '25 global ratings',
#  '1,886 global ratings',
#  '4,278 global ratings',
#  '227 global ratings',
#  '668 global ratings',
#  '489 global ratings',
#  '142 global ratings',
#  '4,278 global ratings',
#  '22 global ratings',
#  '1,127 global ratings',
#  '1,886 global ratings',
#  '405 global ratings',
# ...

# %%
return_or_exchange=[]
for i in urls[:201]:
    driver.get(i)
    time.sleep(1)
    
    try:
        return_delivery=driver.find_element_by_xpath("//a[@class='a-size-small a-link-normal a-text-normal'][1]")
        return_or_exchange.append(return_delivery.text)
    except:
        return_or_exchange.append('-')
        sleep(1)

# %%
return_or_exchange
# Out:
# ['Pay on Delivery',
#  'Pay on Delivery',
#  'Pay on Delivery',
#  'Pay on Delivery',
#  'Pay on Delivery',
#  'Pay on Delivery',
#  'Pay on Delivery',
#  'Pay on Delivery',
#  'Pay on Delivery',
#  'Pay on Delivery',
#  '10 Days Returns',
#  'Pay on Delivery',
#  'Pay on Delivery',
#  'Pay on Delivery',
#  'Pay on Delivery',
#  'Pay on Delivery',
#  'Pay on Delivery',
#  'Pay on Delivery',
#  '10 Days Returns',
#  'Pay on Delivery',
#  'Pay on Delivery',
#  'Pay on Delivery',
#  'Pay on Delivery',
#  'Pay on Delivery',
#  'Pay on Delivery',
#  'Pay on Delivery',
#  'Pay on Delivery',
#  'Pay on Delivery',
#  'Pay on Delivery',
#  'Pay on Delivery',
#  'Pay on Delivery',
#  'Pay on Delivery',
#  'Pay on Delivery',
#  'Pay on Delivery',
#  'Pay on Delivery',
#  'Pay on Delivery',
#  '10 Days Returns',
#  'Pay on Delivery',
#  'Pay on Delivery',
#  'Pay on Delivery',
#  'Pay on Delivery',
#  'Pay on Delivery',
#  'Pay on Delivery',
#  'Pay on Delivery',
#  'Pay on Delivery',
# ...

# %%
expected_delivery=[]
for i in urls[:201]:
    driver.get(i)
    time.sleep(1)
    
    try:
        delivery=driver.find_element_by_xpath('//div[@id="ddmDeliveryMessage"]')
        expected_delivery.append(delivery.text.replace("\n", " or "))
    except:
        expected_delivery.append('-')
        sleep(1)

# %%
expected_delivery
# Out:
# ['FREE delivery: Friday, Sep 24 Details',
#  'FREE delivery: Wednesday, Sep 22 Details or Fastest delivery: Tomorrow or Order within 2 hrs and 8 mins Details',
#  'FREE delivery: Thursday, Sep 23 Details or Fastest delivery: Tomorrow or Order within 2 hrs and 8 mins Details',
#  'FREE delivery: Wednesday, Sep 22 Details or Fastest delivery: Tomorrow or Order within 2 hrs and 8 mins Details',
#  'FREE delivery: Thursday, Sep 23 Details or Fastest delivery: Wednesday, Sep 22 or Order within 2 hrs and 53 mins Details',
#  'FREE delivery: Wednesday, Sep 22 Details or Fastest delivery: Tomorrow or Order within 2 hrs and 7 mins Details',
#  'FREE delivery: Wednesday, Sep 22 Details or Fastest delivery: Tomorrow or Order within 2 hrs and 52 mins Details',
#  'FREE delivery: Wednesday, Sep 22 Details or Fastest delivery: Tomorrow or Order within 2 hrs and 7 mins Details',
# ...

# %%
len(expected_delivery)
# Out:
# 201

# %%
availability=[]
for i in urls[:201]:
    driver.get(i)
    time.sleep(1)
    
    try:
        stock=driver.find_element_by_xpath('//span[@class="a-size-medium a-color-success"]')
        availability.append(stock.text)
    except:
        availability.append('out_of_stock')
        sleep(1)

# %%
len(availability)
# Out:
# 201

# %%
availability
# Out:
# ['In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'Only 3 left in stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'out_of_stock',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  'In stock.',
#  '',
#  'In stock.',
# ...

# %%
other_details=[]
for i in urls[:201]:
    driver.get(i)
    time.sleep(1)
    
    try:
        details=driver.find_element_by_xpath("//div[@id='detailBullets_feature_div']")
        other_details.append(details.text.replace("\n","  "))
    except:
        other_details.append('--')
        sleep(1)

# %%
len(other_details)
# Out:
# 201

# %%
other_details
# Out:
# ['Product Dimensions : 32 x 12 x 24 cm; 800 Grams  Date First Available : 20 June 2019  Manufacturer : Lavie  ASIN : B07T9GB7RN  Item model number : HDFQ674238N3  Country of Origin : China  Department : Women  Manufacturer : Lavie, Bagzone Lifestyle Pvt Ltd | | LAVIE 402, Ackruti Star, MIDC Central Road, Andheri East, Mumbai – 400093.  Packer : Bagzone Lifestyles Pvt Ltd | LAVIE 402, Ackruti Star, MIDC Central Road, Andheri East, Mumbai – 400093. Mr Praveen tainwala :- 9987959922  Importer : Imporated & Marketed ByBagzone Lifestyles Pvt Ltd | LAVIE 402, Ackruti Star, MIDC Central Road, Andheri East, Mumbai – 400093. Mr Praveen tainwala :- 9987959922  Item Weight : 800 g  Item Dimensions LxWxH : 32 x 12 x 24 Centimeters  Net Quantity : 1 Numbers  Included Components : HANDBAG PROMO ONLINE PREMIUM  Generic Name : Handbag',
# ...

# %%
import pandas as pd

# %%
handbags=pd.DataFrame({})
handbags['Product']= products[:198]
handbags['Brand']= brand[:198]
handbags['Price']= price[:198]
handbags['Ratings']= ratings[:198]
handbags['Number of Ratings']= number_of_ratings[:198]
handbags['Expected_Delivery']=expected_delivery[:198]
handbags['Return/Exchange']= return_or_exchange[:198]
handbags['Availability']= availability[:198]
handbags['Product_Details']= other_details[:198]
handbags['Product_Url']= urls[:198]
handbags
# Out:
#                                                Product    Brand  Price  \
# 0                  Ushawu Dome Satchel Women's Handbag    Lavie    875
# 1                                Pavo Women’s Tote Bag    Lavie  4,499
# 2                              Betula Women's Tote Bag    Lavie  1,199
# 3      Women's PU Leather Handbag Combo (4-teddy-pink)    Lavie  1,462
# 4           Women's Catlin Handbag (Maroon) (FSB-1033)  Fostelo    569
# ..                                                 ...      ...    ...
# 193                   Women's Handbag (Set of 2, Pink)    Aisna    389
# 194                        Women's Bowling Bag (Green)  Fostelo    649
# 195  Women's Handbag in Premium Navy Blue Color Sho...   Baggit    689
# 196  Leatherette Handbags For Women's Ladies (Chain...  Bellina    699
# 197                       Women's Tote Handbag (Black)   Mammon    749
#
#           Ratings     Number of Ratings  \
# 0      4 out of 5  1,352 global ratings
# ...

# %%
handbags.to_csv('Handbags.csv')

# %%
handbags
# Out:
#                                                Product    Brand  Price  \
# 0                  Ushawu Dome Satchel Women's Handbag    Lavie    875
# 1                                Pavo Women’s Tote Bag    Lavie  4,499
# 2                              Betula Women's Tote Bag    Lavie  1,199
# 3      Women's PU Leather Handbag Combo (4-teddy-pink)    Lavie  1,462
# 4           Women's Catlin Handbag (Maroon) (FSB-1033)  Fostelo    569
# ..                                                 ...      ...    ...
# 193                   Women's Handbag (Set of 2, Pink)    Aisna    389
# 194                        Women's Bowling Bag (Green)  Fostelo    649
# 195  Women's Handbag in Premium Navy Blue Color Sho...   Baggit    689
# 196  Leatherette Handbags For Women's Ladies (Chain...  Bellina    699
# 197                       Women's Tote Handbag (Black)   Mammon    749
#
#           Ratings     Number of Ratings  \
# 0      4 out of 5  1,352 global ratings
# ...

# %%
3: Write a python program to access the search bar and search button on images.google.com and
scrape 100 images each for keywords ‘fruits’, ‘cars’ and ‘Machine Learning’.

# %%
import os
import selenium
from selenium import webdriver
import time
from PIL import Image
import io
import requests
from selenium.common.exceptions import ElementClickInterceptedException
# Out:
# C:\Users\IFATH FATIMA\anaconda3\lib\site-packages\requests\__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.6) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
driver = webdriver.Chrome(r"C:\Users\IFATH FATIMA\Downloads\chromedriver_win32 (6)\chromedriver")
url='https://images.google.com/'
driver.get(url)
# Out:
# <ipython-input-62-848bd92c6f6d>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r"C:\Users\IFATH FATIMA\Downloads\chromedriver_win32 (6)\chromedriver")

# %%
input_search1=driver.find_element_by_xpath('//input[@class="gLFyf gsfi"]')
input_search1
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="99f349b4f580635b6ab812febe19e022", element="d7f9a035-8d3d-489d-b171-0981d30d1b67")>

# %%
input_search1.send_keys("Fruits")

# %%
button=driver.find_element_by_xpath('//button[@class="Tg7LZd"]')
button
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="99f349b4f580635b6ab812febe19e022", element="4d01b5b1-60e9-41d2-8191-469b50d4c445")>

# %%
button.click()

# %%
driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
time.sleep(3)#sleep_between_interactions

# %%
imgResults = driver.find_elements_by_xpath("//img[contains(@class,'Q4LuWd')]")
totalResults=100

# %%
len(imgResults)
# Out:
# 200

# %%
imgResults
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="99f349b4f580635b6ab812febe19e022", element="a280d3ed-4c1b-48fd-9afa-ce7cfc7ed5d1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99f349b4f580635b6ab812febe19e022", element="a182a028-4c8a-40a6-a70a-4139593229bc")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99f349b4f580635b6ab812febe19e022", element="187493ff-58c2-402b-a2c4-4653bca01b83")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99f349b4f580635b6ab812febe19e022", element="75af4c52-6577-4b7c-8793-cab058309f6f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99f349b4f580635b6ab812febe19e022", element="db9a3266-db34-444d-9f78-cc02aa80668b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="99f349b4f580635b6ab812febe19e022", element="426f512c-84a9-4ba4-b540-6a04f762749a")>,
# ...

# %%
img_urls = []
for i in range(0, 100):
    img = imgResults[i]
    try:
        img.click()
        time.sleep(2)
        actual_images = driver.find_elements_by_css_selector('img.n3VNCb')
        for actual_image in actual_images:
            if actual_image.get_attribute('src') and 'https' in actual_image.get_attribute('src'):
                img_urls.append(actual_image.get_attribute('src'))
                
    except ElementClickInterceptedException or ElementNotInteractableException as err:
        print(err)
# Out:
# C:\Users\IFATH FATIMA\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:742: UserWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   warnings.warn("find_elements_by_* commands are deprecated. Please use find_elements() instead")
# Message: element click intercepted: Element <img data-ils="4" jsaction="rcuQ6b:trigger.M8vzZb;" class="rg_i Q4LuWd" jsname="Q4LuWd" width="241" height="209" alt="8 Best Power Fruits for Better Health" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR2A9Pch7uvfGdKgfIznLJs2dqlyZTVij4jVw&amp;usqp=CAU"> is not clickable at point (403, 636). Other element would receive the click: <div jsname="r5xl4" class="islrc" style="width: 551px;">...</div>
#   (Session info: chrome=93.0.4577.82)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x00F9D403+2479107]
# 	Ordinal0 [0x00F37D51+2063697]
# 	Ordinal0 [0x00E420C8+1056968]
# 	Ordinal0 [0x00E72A59+1256025]
# 	Ordinal0 [0x00E70D7B+1248635]
# ...

# %%
img_urls
# Out:
# ['https://images-na.ssl-images-amazon.com/images/I/91WdMqaFL6L.jpg',
#  'https://i.ytimg.com/vi/PY2OxP_jMZ0/maxresdefault.jpg',
#  'https://www.healthyeating.org/images/default-source/home-0.0/nutrition-topics-2.0/general-nutrition-wellness/2-2-2-3foodgroups_fruits_detailfeature.jpg?sfvrsn=64942d53_4',
#  'https://hips.hearstapps.com/hmg-prod.s3.amazonaws.com/images/assortment-of-colorful-ripe-tropical-fruits-top-royalty-free-image-995518546-1564092355.jpg',
#  'https://i.pinimg.com/originals/8a/6b/44/8a6b4439916eb8c3d52cbc2de66150d7.png',
#  'https://images-na.ssl-images-amazon.com/images/I/71dCugrtH4L.jpg',
#  'https://www.worldatlas.com/r/w1200/upload/46/cb/e1/shutterstock-252338818.jpg',
#  'https://www.dole.com/-/media/project/dole/produce-images/headers/dole-produce-fruit-medley.png?h=630&w=1200&rev=1416123f2d094cd1b7494365948214be&hash=52F3DBCB5BDC2F5C3528358D1ABF9D2E',
#  'https://i.pinimg.com/originals/c2/2e/32/c22e324ceb7a7f5b1fc69152dd68d85b.jpg',
# ...

# %%
len(img_urls)
# Out:
# 254

# %%
import requests
import os

# %%
os.chdir('C:/fruits.imgs')
baseDir=os.getcwd()

for i, url in enumerate(img_urls[0:100]):
    file_name = f"{i:100}.jpg"    
    try:
        image_content = requests.get(url).content

    except Exception as e:
        print(f"ERROR - COULD NOT DOWNLOAD {url} - {e}")

    try:
        image_file = io.BytesIO(image_content)
        image = Image.open(image_file).convert('RGB')
        
        file_path = os.path.join(baseDir, file_name)
        
        with open(file_path, 'wb') as f:
            image.save(f, "JPEG", quality=85)
        print(f"SAVED - {url} - AT: {file_path}")
  
    except Exception as e:
        print(f"ERROR - COULD NOT SAVE {url} - {e}")
# Out:
# SAVED - https://images-na.ssl-images-amazon.com/images/I/91WdMqaFL6L.jpg - AT: C:\fruits.imgs\                                                                                                   0.jpg
# SAVED - https://i.ytimg.com/vi/PY2OxP_jMZ0/maxresdefault.jpg - AT: C:\fruits.imgs\                                                                                                   1.jpg
# SAVED - https://www.healthyeating.org/images/default-source/home-0.0/nutrition-topics-2.0/general-nutrition-wellness/2-2-2-3foodgroups_fruits_detailfeature.jpg?sfvrsn=64942d53_4 - AT: C:\fruits.imgs\                                                                                                   2.jpg
# SAVED - https://hips.hearstapps.com/hmg-prod.s3.amazonaws.com/images/assortment-of-colorful-ripe-tropical-fruits-top-royalty-free-image-995518546-1564092355.jpg - AT: C:\fruits.imgs\                                                                                                   3.jpg
# ...

# %%
driver = webdriver.Chrome(r"C:\Users\IFATH FATIMA\Downloads\chromedriver_win32 (6)\chromedriver")
url='https://images.google.com/'
driver.get(url)
# Out:
# <ipython-input-121-848bd92c6f6d>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r"C:\Users\IFATH FATIMA\Downloads\chromedriver_win32 (6)\chromedriver")

# %%
input_search2=driver.find_element_by_xpath('//input[@class="gLFyf gsfi"]')
input_search2
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="fe81263f9964229123a196de90c050bd", element="224f510e-7eef-4337-9695-875a5be1a6e7")>

# %%
input_search2.send_keys("Cars")

# %%
button=driver.find_element_by_xpath('//button[@class="Tg7LZd"]')
button
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="fe81263f9964229123a196de90c050bd", element="52ab90b4-d0e6-40e8-8041-b4a8c5743ebc")>

# %%
button.click()

# %%
driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
time.sleep(2)

# %%
imgResults2 = driver.find_elements_by_xpath("//img[contains(@class,'Q4LuWd')]")
totalResults=100

# %%
len(imgResults2)
# Out:
# 100

# %%
imgRsults2=[]

# %%
imgResults2
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="fe81263f9964229123a196de90c050bd", element="eb62e4b6-3875-45b3-9e4f-a0297123ca6b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fe81263f9964229123a196de90c050bd", element="fd58389d-a899-4773-9ff7-defcd55130be")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fe81263f9964229123a196de90c050bd", element="31401b62-112a-408c-9938-c11ac3899a0a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fe81263f9964229123a196de90c050bd", element="cb0e828f-7396-4232-a8d8-1a5f3f74a2e9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fe81263f9964229123a196de90c050bd", element="56e0095a-8c57-45ee-b197-d2de7338c4c9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fe81263f9964229123a196de90c050bd", element="a509c2af-6254-46a0-b145-d7e2f33d95fa")>,
# ...

# %%
img_urls2 = []
for i in  range(0, 100):
    img=imgResults2[i]
    try:
        img.click()
        time.sleep(2)
        actual_images = driver.find_elements_by_css_selector('img.n3VNCb')
        for actual_image in actual_images:
            if actual_image.get_attribute('src') and 'https' in actual_image.get_attribute('src'):
                img_urls2.append(actual_image.get_attribute('src'))
    except ElementClickInterceptedException or ElementNotInteractableException as err:
        print(err)
# Out:
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# <ipython-input-139-f094516b6d23> in <module>
#       3     img=imgResults2[i]
#       4     try:
# ----> 5         img.click()
#       6         time.sleep(2)
#       7         actual_images = driver.find_elements_by_css_selector('img.n3VNCb')
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      78     def click(self) -> None:
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     691             params = {}
#     692         params['id'] = self._id
# --> 693         return self._parent.execute(command, params)
#     694
#     695     def find_element(self, by=By.ID, value=None):
#
# ...

# %%
img_urls2
# Out:
# ['https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSWGvBIMKjRqiKRVEeGP4SU5-ODjSYCNNzXBw&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSWGvBIMKjRqiKRVEeGP4SU5-ODjSYCNNzXBw&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRAB7kg-BzgmUKqi4Vm7_y93lcrv0YaHc-9QA&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSWGvBIMKjRqiKRVEeGP4SU5-ODjSYCNNzXBw&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRAB7kg-BzgmUKqi4Vm7_y93lcrv0YaHc-9QA&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSPTXYOJCG-NmDxyu_Rzo6oO5OMgCdRWgTkkA&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRAB7kg-BzgmUKqi4Vm7_y93lcrv0YaHc-9QA&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSPTXYOJCG-NmDxyu_Rzo6oO5OMgCdRWgTkkA&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRTvXPsRrxjeEaUosRdPe6lIuUFYhkJasI1CQ&usqp=CAU',
# ...

# %%
len(img_urls2)
# Out:
# 180

# %%
import requests
import os

# %%
os.chdir('C:/cars')
baseDir=os.getcwd()

for i, url in enumerate(img_urls[0:100]):
    file_name = f"{i:100}.jpg"    
    try:
        image_content = requests.get(url).content

    except Exception as e:
        print(f"ERROR - COULD NOT DOWNLOAD {url} - {e}")

    try:
        image_file = io.BytesIO(image_content)
        image = Image.open(image_file).convert('RGB')
        
        file_path = os.path.join(baseDir, file_name)
        
        with open(file_path, 'wb') as f:
            image.save(f, "JPEG", quality=85)
        print(f"SAVED - {url} - AT: {file_path}")
  
    except Exception as e:
        print(f"ERROR - COULD NOT SAVE {url} - {e}")
# Out:
# SAVED - https://images-na.ssl-images-amazon.com/images/I/91WdMqaFL6L.jpg - AT: C:\cars\                                                                                                   0.jpg
# SAVED - https://i.ytimg.com/vi/PY2OxP_jMZ0/maxresdefault.jpg - AT: C:\cars\                                                                                                   1.jpg
# SAVED - https://www.healthyeating.org/images/default-source/home-0.0/nutrition-topics-2.0/general-nutrition-wellness/2-2-2-3foodgroups_fruits_detailfeature.jpg?sfvrsn=64942d53_4 - AT: C:\cars\                                                                                                   2.jpg
# SAVED - https://hips.hearstapps.com/hmg-prod.s3.amazonaws.com/images/assortment-of-colorful-ripe-tropical-fruits-top-royalty-free-image-995518546-1564092355.jpg - AT: C:\cars\                                                                                                   3.jpg
# ...

# %%
import os
import selenium
from selenium import webdriver
import time
from PIL import Image
import io
import requests
from selenium.common.exceptions import ElementClickInterceptedException
# Out:
# C:\Users\IFATH FATIMA\anaconda3\lib\site-packages\requests\__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.6) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
driver = webdriver.Chrome(r"C:\Users\IFATH FATIMA\Downloads\chromedriver_win32 (6)\chromedriver")
url='https://images.google.com/'
driver.get(url)
# Out:
# <ipython-input-2-848bd92c6f6d>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r"C:\Users\IFATH FATIMA\Downloads\chromedriver_win32 (6)\chromedriver")

# %%
input_search3=driver.find_element_by_xpath('//input[@class="gLFyf gsfi"]')
input_search3
# Out:
# C:\Users\IFATH FATIMA\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:483: UserWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   warnings.warn("find_element_by_* commands are deprecated. Please use find_element() instead")
# <selenium.webdriver.remote.webelement.WebElement (session="5e435b238bc0db64a2410e1733250f7d", element="77fafe0d-723a-41bf-b8e8-794f7d381536")>

# %%
input_search3.send_keys("Machine Learning")

# %%
button=driver.find_element_by_xpath('//button[@class="Tg7LZd"]')
button
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="5e435b238bc0db64a2410e1733250f7d", element="da114778-ee62-4f76-a341-45578fcf6887")>

# %%
button.click()

# %%
driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
time.sleep(2)

# %%
imgResults3 = driver.find_elements_by_xpath("//img[contains(@class,'Q4LuWd')]")
totalResults=100

# %%
len(imgResults3)
# Out:
# 300

# %%
imgRsults3=[]
imgResults3
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="5e435b238bc0db64a2410e1733250f7d", element="a5be66df-01a0-4e79-bf1a-a00360fcd3b9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5e435b238bc0db64a2410e1733250f7d", element="e2c666d9-50fe-4aab-a4b4-4b96b606bb11")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5e435b238bc0db64a2410e1733250f7d", element="5bcbe0f1-6ec6-47e1-b82f-c4514b629cc7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5e435b238bc0db64a2410e1733250f7d", element="938f7840-8035-49b1-a375-08b7fac723cb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5e435b238bc0db64a2410e1733250f7d", element="99b3b702-2355-4155-9248-8f375cea9e84")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="5e435b238bc0db64a2410e1733250f7d", element="0f393960-4afc-49c9-a841-b7e1a752ee79")>,
# ...

# %%
img_urls3 = []
for i in  range(0, 100):
    img = imgResults3[i]
    try:
        img.click()
        time.sleep(2)
        actual_images = driver.find_elements_by_css_selector('img.n3VNCb')
        for actual_image in actual_images:
            if actual_image.get_attribute('src') and 'https' in actual_image.get_attribute('src'):
                img_urls3.append(actual_image.get_attribute('src'))
    except ElementClickInterceptedException or ElementNotInteractableException as err:
        print(err)
# Out:
# C:\Users\IFATH FATIMA\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:742: UserWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   warnings.warn("find_elements_by_* commands are deprecated. Please use find_elements() instead")

# %%
img_urls3
# Out:
# ['https://cdn.britannica.com/s:800x450,c:crop/40/216540-138-14385CFE/How-machine-learning-is-predicting-synthetic-products.jpg',
#  'https://www.expert.ai/wp-content/uploads/2017/03/machine-learning-definition.jpeg',
#  'https://www.readspeaker.ai/wp-content/uploads/2021/05/deep-learning-vs-machine-learning-readspeaker.jpg',
#  'https://blog.integral-system.fr/wp-content/uploads/2020/02/33797061.jpg',
#  'https://www.iberdrola.com/wcorp/gc/prod/en_US/comunicacion/machine_learning_key_res/machine_learning_792x214.jpg',
#  'https://www.simplilearn.com/ice9/free_resources_article_thumb/Deep-Learning-vs-Machine-Learning.jpg',
#  'https://www.einfochips.com/blog/wp-content/uploads/2018/11/how-to-develop-machine-learning-applications-for-business-featured.jpg',
#  'https://velocityglobal.com/wp-content/uploads/2019/02/Blog-Images-Forget-Machine-Learning-Humans-Still-Have-a-Lot-to-Learn-Part-II.jpg',
#  'https://media.geeksforgeeks.org/wp-content/cdn-uploads/machineLearning3.png',
# ...

# %%
len(img_urls3)
# Out:
# 250

# %%
os.chdir('C:/Machine Learning')
baseDir=os.getcwd()

for i, url in enumerate(img_urls3[0:100]):
    file_name = f"{i:100}.jpg"    
    try:
        image_content = requests.get(url).content

    except Exception as e:
        print(f"ERROR - COULD NOT DOWNLOAD {url} - {e}")

    try:
        image_file = io.BytesIO(image_content)
        image = Image.open(image_file).convert('RGB')
        
        file_path = os.path.join(baseDir, file_name)
        
        with open(file_path, 'wb') as f:
            image.save(f, "JPEG", quality=85)
                       
        print(f"SAVED - {url} - AT: {file_path}")
  
    except Exception as e:
        print(f"ERROR - COULD NOT SAVE {url} - {e}")
# Out:
# SAVED - https://cdn.britannica.com/s:800x450,c:crop/40/216540-138-14385CFE/How-machine-learning-is-predicting-synthetic-products.jpg - AT: C:\Machine Learning\                                                                                                   0.jpg
# SAVED - https://www.expert.ai/wp-content/uploads/2017/03/machine-learning-definition.jpeg - AT: C:\Machine Learning\                                                                                                   1.jpg
# ERROR - COULD NOT SAVE https://www.readspeaker.ai/wp-content/uploads/2021/05/deep-learning-vs-machine-learning-readspeaker.jpg - cannot identify image file <_io.BytesIO object at 0x0000024B3AC83C20>
# SAVED - https://blog.integral-system.fr/wp-content/uploads/2020/02/33797061.jpg - AT: C:\Machine Learning\                                                                                                   3.jpg
# ...

# %% [markdown]
# 4.Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on
# www.flipkart.com and scrape following details for all the search results displayed on 1st page.
# Details to be scraped: “Brand Name”, “Smartphone name”, “Colour”, “RAM”,
# “Storage(ROM)”, “Primary Camera”, “Secondary Camera”, “Display Size”, “Display
# Resolution”, “Processor”, “Processor Cores”, “Battery Capacity”, “Price”, “Product URL”.
# Incase if any of the details is missing then replace it by “- “. Save your results in a dataframe
# and CSV.

# %%
import selenium
import pandas as pd  
from selenium import webdriver
from time import sleep
import time
from selenium.common.exceptions import NoSuchElementException

# %%
driver = webdriver.Chrome(r"C:\Users\IFATH FATIMA\Downloads\chromedriver_win32 (6)\chromedriver")
url='https://www.flipkart.com/'
driver.get(url)
# Out:
# <ipython-input-410-0ec8c5d6d33f>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r"C:\Users\IFATH FATIMA\Downloads\chromedriver_win32 (6)\chromedriver")

# %%
input_search=driver.find_element_by_class_name("_3704LK")
input_search
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="4f21b7e882ebb3b2112db4a1d7512d19", element="0f21bf56-c465-4006-803c-74a57701931d")>

# %%
input_search.send_keys("OPPO")

# %%
button_click=driver.find_element_by_class_name("L0Z3Pu")
button_click.click()

# %%
urls_tags=driver.find_elements_by_xpath('//a[@class="_1fQZEK"]')
urls_tags
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4f21b7e882ebb3b2112db4a1d7512d19", element="8cd418a8-3f92-4e7b-bcfb-4e542c55708d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4f21b7e882ebb3b2112db4a1d7512d19", element="28d16800-5b0e-42e0-8a20-5706a5938f91")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4f21b7e882ebb3b2112db4a1d7512d19", element="4f2ead04-193e-47c8-870e-28daa11f9bab")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4f21b7e882ebb3b2112db4a1d7512d19", element="28e22563-7b38-43bb-9a10-9b42d915a2c6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4f21b7e882ebb3b2112db4a1d7512d19", element="d6bd5a19-0049-48a9-bd48-a4d4a377ffee")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4f21b7e882ebb3b2112db4a1d7512d19", element="7f2f0a96-5b37-4cce-855b-2be52f3117c3")>,
# ...

# %%
urls=[]
for i in urls_tags:
    urls.append(i.get_attribute("href"))
urls
# Out:
# ['https://www.flipkart.com/oppo-a12-deep-blue-64-gb/p/itmfc859cdf39e01?pid=MOBFZCPFGTXCR6K4&lid=LSTMOBFZCPFGTXCR6K4MZ8PJB&marketplace=FLIPKART&q=OPPO&store=tyy%2F4io&srno=s_1_1&otracker=search&otracker1=search&fm=SEARCH&iid=7692bbff-ad15-4422-b1e1-6338cdb8013f.MOBFZCPFGTXCR6K4.SEARCH&ppt=hp&ppn=homepage&ssid=ngzzk5z29s0000001632502036052&qH=67843bc0e7e7b09c',
#  'https://www.flipkart.com/oppo-a12-deep-blue-32-gb/p/itmfc859cdf39e01?pid=MOBFZCPFHAT4RCE8&lid=LSTMOBFZCPFHAT4RCE8CIDDGJ&marketplace=FLIPKART&q=OPPO&store=tyy%2F4io&srno=s_1_2&otracker=search&otracker1=search&fm=SEARCH&iid=7692bbff-ad15-4422-b1e1-6338cdb8013f.MOBFZCPFHAT4RCE8.SEARCH&ppt=hp&ppn=homepage&ssid=ngzzk5z29s0000001632502036052&qH=67843bc0e7e7b09c',
# ...

# %%
price=[]
price_tag=driver.find_elements_by_xpath('//div[@class="_30jeq3 _1_WHN1"]')
for i in price_tag:
    price.append(i.text)
price
# Out:
# ['₹10,490',
#  '₹9,490',
#  '₹9,490',
#  '₹10,490',
#  '₹9,490',
#  '₹11,990',
#  '₹13,990',
#  '₹13,990',
#  '₹13,989',
#  '₹15,990',
#  '₹15,990',
#  '₹10,490',
#  '₹17,990',
#  '₹17,990',
#  '₹19,990',
#  '₹11,650',
#  '₹12,170',
#  '₹15,999',
#  '₹15,999',
#  '₹19,990',
#  '₹19,990',
#  '₹11,990',
#  '₹14,990',
#  '₹15,490']

# %%
len(price)
# Out:
# 24

# %%
smartphone_name=[]
phone_color=[]
phone_ram=[]
phone_storage=[]
camera_primary=[]
camera_secondary=[]
display_size=[]
display_resolution=[]
phone_processor=[]
processor_cores=[]
battery_capacity=[]

# %%
for url in urls:
    driver.get(url)
    time.sleep(2)

    # Finding the Read More button and clicking it
    driver.find_element_by_xpath("//button[@class='_2KpZ6l _1FH0tX']").click()
    time.sleep(2)
    
    # Storing all the table rows
    phone_features=driver.find_elements_by_xpath("//tr[@class='_1s_Smc row']")

    # Iterating through the Table rows to get required data
    for name in phone_features:
        text1=name.find_element_by_xpath(td[1]).text # Storing text for first Table Data for each row to check 'if' condition

        # Extracting Model name
        try:
            if text1=='Model Name':
                smartphone_name.append(name.find_element_by_xpath("td[2]").text)
        except:
            smartphone_name.append('-')
        try:
            if text1=='Color':
                phone_color.append(name.find_element_by_xpath("td[2]").text)
        except:
            phone_color.append('-')
        try:
            if text1=='Display Size':
                display_size.append(name.find_element_by_xpath("td[2]").text)
        except:
            display_size.append('-')
                
        try:
            if text1=='Resolution':
                display_resolution.append(name.find_element_by_xpath("td[2]").text)
        except:
            display_resolution.append('-')
        try:
            if text1=='Processor Type':
                 phone_processor.append(name.find_element_by_xpath("td[2]").text)
        except:
            phone_processor.append("-")
        
        # Extracting Cores in Processor
        try:
            if text1=='Processor Core':
                processor_cores.append(name.find_element_by_xpath("td[2]").text)
        except:
            processor_cores.append('-')
                

        # Extracting Internal Storage(ROM)
        try:
            if text1=='Internal Storage':
                phone_storage.append(name.find_element_by_xpath("td[2]").text)
        except:
            phone_storage.append('-')

        # Extracting RAM Memory
        try:
            if text1=='RAM':
                phone_ram.append(name.find_element_by_xpath("td[2]").text)
        except:
            phone_ram.append('-')
                
        # Extracting Primary Camera Details
        try:
            if text1=='Primary Camera':
                camera_primary.append(name.find_element_by_xpath("td[2]").text)
        except:
            camera_primary.append('-')

        # Extracting Secondary Camera Details

        try:
            if text1=='Secondary Camera':
                camera_secondary.append(name.find_element_by_xpath("td[2]").text)
        except:
            camera_secondary.append('-')

        # Extracting Battery Capacity
        try:
            if text1=='Battery Capacity':
                battery_capacity.append(name.find_element_by_xpath("td[2]").text)
        except:
            battery_capacity.append('-')

# %%
print(smartphone_name)
print(phone_color)
print(phone_ram)
print(phone_storage)
print(camera_primary)
print(camera_secondary)
print(display_size)
print(display_resolution)
print(phone_processor)
print(processor_cores)
print(battery_capacity)
# Out:
# ['A12', 'A12', 'A12', 'A12', 'A12', 'A53', 'A53', 'A53', 'A53', 'A53s 5G', 'A53s 5G', 'A33', 'A53s 5G', 'A53s 5G', 'F17 Pro', 'A31', 'A31', 'A53', 'A53', 'F17 Pro', 'F17 Pro', 'A31', 'A54', 'A54']
# ['Deep Blue', 'Deep Blue', 'Blue', 'Flowing Silver', 'Flowing Silver', 'Moonlight Black', 'Moonlight Black', 'Mint Cream', 'Electric Black', 'Ink Black', 'Crystal Blue', 'Moonlight Black', 'Crystal Blue', 'Ink Black', 'Matte Black', 'Mystery Black', 'Fantasy White', 'Electric Black', 'Fancy Blue', 'Magic Blue', 'Metallic White', 'Lake Green', 'Moonlight Gold', 'Moonlight Gold']
# ['4 GB', '3 GB', '3 GB', '4 GB', '3 GB', '4 GB', '6 GB', '6 GB', '4 GB', '6 GB', '6 GB', '3 GB', '8 GB', '8 GB', '8 GB', '4 GB', '4 GB', '6 GB', '6 GB', '8 GB', '8 GB', '4 GB', '4 GB', '4 GB']
# ...

# %%
brand_tag=driver.find_elements_by_xpath("//div[@class='_4rR01T']")
brand_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4f21b7e882ebb3b2112db4a1d7512d19", element="fb0d4a56-72cd-4450-823b-a0b9850b91ef")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4f21b7e882ebb3b2112db4a1d7512d19", element="e1515de6-b050-4d09-ad0a-1c3732cb3d37")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4f21b7e882ebb3b2112db4a1d7512d19", element="e66b7df8-1c3f-4b0b-8772-f47a26004205")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4f21b7e882ebb3b2112db4a1d7512d19", element="3f6de6d4-6e69-4d03-a00e-60783cd9ce2a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4f21b7e882ebb3b2112db4a1d7512d19", element="0eb5666a-2626-41e8-98d7-0328eb19b71a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4f21b7e882ebb3b2112db4a1d7512d19", element="3441a724-3710-4d0c-adba-49f184c5517f")>,
# ...

# %%
brand=[]
for i in brand_tag:
    brand.append(i.text)
brand
# Out:
# ['OPPO A12 (Black, 32 GB)',
#  'OPPO A12 (Deep Blue, 64 GB)',
#  'OPPO A12 (Deep Blue, 32 GB)',
#  'OPPO A12 (Blue, 32 GB)',
#  'OPPO A12 (Flowing Silver, 64 GB)',
#  'OPPO A12 (Flowing Silver, 32 GB)',
#  'OPPO A53 (Moonlight Black, 64 GB)',
#  'OPPO A53 (Mint Cream, 64 GB)',
#  'OPPO A53 (Moonlight Black, 128 GB)',
#  'OPPO A53 (Mint Cream, 128 GB)',
#  'OPPO A53 (Electric Black, 64 GB)',
#  'OPPO A53s 5G (Ink Black, 128 GB)',
#  'OPPO A53s 5G (Crystal Blue, 128 GB)',
#  'OPPO A33 (Moonlight Black, 32 GB)',
#  'OPPO F17 Pro (Matte Black, 128 GB)',
#  'OPPO A53s 5G (Crystal Blue, 128 GB)',
#  'OPPO A53s 5G (Ink Black, 128 GB)',
#  'OPPO A31 (Mystery Black, 64 GB)',
#  'OPPO A53 (Electric Black, 128 GB)',
#  'OPPO A53 (Fancy Blue, 128 GB)',
#  'OPPO A53 (Fairy White, 128 GB)',
#  'OPPO F17 Pro (Magic Blue, 128 GB)',
#  'OPPO F17 Pro (Metallic White, 128 GB)',
#  'OPPO A31 (Lake Green, 64 GB)']

# %%
len(brand)
# Out:
# 24

# %%
print(len(smartphone_name),len(phone_color),len(phone_storage),len(phone_ram),len(camera_primary),len(camera_secondary),
      len(display_size),len(display_resolution),len(phone_processor),len(processor_cores),len(battery_capacity))
# Out:
# 24 24 24 24 24 24 24 24 24 24 24

# %%
df=pd.DataFrame({})
df["Brand"]=brand[:24]
df["Smartphone_name"]= smartphone_name[:24]
df["Color"] = phone_color[:24]
df["RAM"]=phone_ram[:24]
df["ROM"]=phone_storage[:24]
df["Camera_Primary"]=camera_primary[:24]
df["Camera_Secondary"]=camera_secondary[:24]
df["Display_size"]=display_size[:24]
df["Display_Resolution"]=display_resolution[:24]
df["Processor"]=phone_processor[:24]
df["Processor_cores"]=processor_cores[:24]
df["Battery_Capacity"]=battery_capacity[:24]
df["Price"]=price[:24]
df["Product_URL"]=urls[:24]
df
# Out:
#                                     Brand Smartphone_name            Color  \
# 0                 OPPO A12 (Black, 32 GB)             A12        Deep Blue
# 1             OPPO A12 (Deep Blue, 64 GB)             A12        Deep Blue
# 2             OPPO A12 (Deep Blue, 32 GB)             A12             Blue
# 3                  OPPO A12 (Blue, 32 GB)             A12   Flowing Silver
# 4        OPPO A12 (Flowing Silver, 64 GB)             A12   Flowing Silver
# 5        OPPO A12 (Flowing Silver, 32 GB)             A53  Moonlight Black
# 6       OPPO A53 (Moonlight Black, 64 GB)             A53  Moonlight Black
# 7            OPPO A53 (Mint Cream, 64 GB)             A53       Mint Cream
# 8      OPPO A53 (Moonlight Black, 128 GB)             A53   Electric Black
# 9           OPPO A53 (Mint Cream, 128 GB)         A53s 5G        Ink Black
# 10       OPPO A53 (Electric Black, 64 GB)         A53s 5G     Crystal Blue
# ...

# %% [markdown]
# 5:. Write a program to scrap geospatial coordinates (latitude, longitude) of a city searched on
# google maps

# %%
# !pip install selenium

# %%
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
import selenium
import pandas as pd  
from selenium import webdriver
from time import sleep
import time
from selenium.webdriver.chrome.options import Options

# %%
driver = webdriver.Chrome(r"C:\Users\IFATH FATIMA\Downloads\chromedriver_win32 (6)\chromedriver.exe")
url="https://www.google.com/maps"
driver.get(url)
# Out:
# <ipython-input-756-40c034ea7118>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r"C:\Users\IFATH FATIMA\Downloads\chromedriver_win32 (6)\chromedriver.exe")

# %%
search_loc = driver.find_element_by_xpath('/html/body/div[3]/div[9]/div[3]/div[1]/div[1]/div[1]/div[2]/form/div/div[3]/div/input[1]')

search_loc.send_keys('Delhi')

button_click=driver.find_element_by_xpath('/html/body/div[3]/div[9]/div[3]/div[1]/div[1]/div[1]/div[2]/div[1]/button').click()

# %%
ActionChains(driver).move_to_element(driver.find_element_by_xpath("//html/body")).context_click().perform()
print(WebDriverWait(driver, 10).until(EC.visibility_of_element_located((By.CSS_SELECTOR, "ul[role='menu']>li div div[class*='text']:nth-of-type(1)"))).text)
# Out:
# 28.64668, 76.81307

# %% [markdown]
# 6:Write a program to scrap details of all the funding deals for second quarter (i.e. July 20 –
# September 20) from trak.in.

# %%
# !pip install bs4
# !pip install requests

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
url="https://trak.in/india-startup-funding-investment-2015/"
page=requests.get(url)
soup=BeautifulSoup(page.text,'lxml')
soup
# Out:
# <!DOCTYPE html>
# <!--[if IE 8]>
# 	<html class="ie ie8" lang="en-US"> <![endif]--><!--[if IE 9]>
# 	<html class="ie ie9" lang="en-US"> <![endif]--><!--[if gt IE 9]><!--><html lang="en-US"> <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="https://trak.in/xmlrpc.php" rel="pingback"/>
# <title>Indian Startup Funding And Investment Chart [2021] – Trak.in – Indian Business of Tech, Mobile &amp; Startups</title>
# <link href="https://trak.in/india-startup-funding-investment-2015/amp/" rel="amphtml"/><meta content="AMP for WP 1.0.64.1" name="generator"/>
# <meta content="en_us" property="og:locale"/>
# <meta content="Trak.in - Indian Business of Tech, Mobile &amp; Startups" property="og:site_name"/>
# <meta content="https://trak.in/india-startup-funding-investment-2015/" property="og:url"/>
# ...

# %%
table_1 = soup.find("table", attrs={"class": "tablepress-id-48"})
table_data = table_1.thead.find_all("tr")

# %%
headings = []
for th in table_data[0].find_all("th"):
    # remove any newlines and extra spaces from left and right
    headings.append(th.text)

print(headings)
# Out:
# ['Sr. No.', 'Date (dd/mm/yyyy)', 'Startup Name', 'Industry / Vertical', 'Sub-Vertical', 'City / Location', "Investors' Name", 'Investment Type', 'Amount (In USD)']

# %%
df=pd.DataFrame(columns=headings)
df
# Out:
# Empty DataFrame
# Columns: [Sr. No., Date (dd/mm/yyyy), Startup Name, Industry / Vertical, Sub-Vertical, City / Location, Investors' Name, Investment Type, Amount (In USD)]
# Index: []

# %%
for row in table_1.find_all("tr")[1:]:
    data=row.find_all("td")
    row_data=[td.text.strip() for td in data]
    length= len(df)
    df.loc[length]=row_data

# %%
#df

# %%
h2=soup.find_all("h2",class_="tablepress-table-name tablepress-table-name-id-48")
h2
# Out:
# [<h2 class="tablepress-table-name tablepress-table-name-id-48">July, 2020</h2>]

# %%
H2=[]
for i in h2:
    H2.append(i.text.replace("\n",""))
H2
# Out:
# ['July, 2020']

# %%
Month=pd.DataFrame({})
Month['MM/Yr']=H2
print(Month)
df
# Out:
#         MM/Yr
# 0  July, 2020
#   Sr. No. Date (dd/mm/yyyy)               Startup Name  \
# 0       1        15/07/2020                   Flipkart
# 1       2        16/07/2020                    Vedantu
# 2       3        16/07/2020                       Crio
# 3       4        14/07/2020                    goDutch
# 4       5        13/07/2020                   Mystifly
# 5       6        09/07/2020               JetSynthesys
# 6       7        10/07/2020                   gigIndia
# 7       8        15/07/2020                  PumPumPum
# 8       9        14/07/2020                       FLYX
# 9      10        13/07/2020  Open Appliances Pvt. Ltd.
#
#         Industry / Vertical  \
# 0                E-commerce
# 1                   EduTech
# 2                   EduTech
# 3                   FinTech
# 4       Airfare Marketplace
# 5  Gaming and Entertainment
# 6               Marketplace
# 7         Automotive Rental
# 8                OTT Player
# 9    Information Technology
#
# ...

# %%
table_2 = soup.find("table", attrs={"class": "tablepress-id-49"})
table_data_2 = table_2.thead.find_all("tr")

# %%
headings = []
for th in table_data_2[0].find_all("th"):
    # remove any newlines and extra spaces from left and right
    headings.append(th.text)

print(headings)
# Out:
# ['Sr. No.', 'Date (dd/mm/yyyy)', 'Startup Name', 'Industry / Vertical', 'Sub-Vertical', 'City / Location', "Investors' Name", 'Investment Type', 'Amount (In USD)']

# %%
df1=pd.DataFrame(columns=headings)
df1
# Out:
# Empty DataFrame
# Columns: [Sr. No., Date (dd/mm/yyyy), Startup Name, Industry / Vertical, Sub-Vertical, City / Location, Investors' Name, Investment Type, Amount (In USD)]
# Index: []

# %%
for row in table_2.find_all("tr")[1:]:
    data_1=row.find_all("td")
    row_data_1=[td.text.strip() for td in data_1]
    length= len(df1)
    df1.loc[length]=row_data_1

# %%
h2=soup.find_all("h2",class_="tablepress-table-name tablepress-table-name-id-49")
h2
# Out:
# [<h2 class="tablepress-table-name tablepress-table-name-id-49">August, 2020</h2>]

# %%
H2=[]
for i in h2:
    H2.append(i.text.replace("\n",""))
H2
# Out:
# ['August, 2020']

# %%
Month=pd.DataFrame({})
Month['MM/Yr']=H2
print(Month)
df1
# Out:
#           MM/Yr
# 0  August, 2020
#    Sr. No. Date (dd/mm/yyyy) Startup Name    Industry / Vertical  \
# 0        1        15/08/2020       Practo             HealthTech
# 1        2        13/08/2020      Medlife             E-commerce
# 2        3        13/08/2020    HungerBox               FoodTech
# 3        4        04/08/2020        Dunzo  Hyper-local Logistics
# 4        5        11/08/2020     Terra.do                EduTech
# 5        6        12/08/2020    Classplus                EduTech
# 6        7        14/08/2020         Niyo                FinTech
# 7        8        10/08/2020    ZestMoney                FinTech
# 8        9        07/08/2020  FreshToHome             E-commerce
# 9       10        13/08/2020      Eduvanz                FinTech
# 10      11        03/08/2020   CrowdPouch                FinTech
# 11      12        04/08/2020   DrinkPrime     Water Purification
#
#                          Sub-Vertical        City / Location  \
# ...

# %%
table_3 = soup.find("table", attrs={"class": "tablepress-id-50"})
table_data_3 = table_3.thead.find_all("tr")

# %%
headings = []
for th in table_data_3[0].find_all("th"):
    # remove any newlines and extra spaces from left and right
    headings.append(th.text)

print(headings)
# Out:
# ['Sr. No.', 'Date (dd/mm/yyyy)', 'Startup Name', 'Industry / Vertical', 'Sub-Vertical', 'City / Location', "Investors' Name", 'Investment Type', 'Amount (In USD)']

# %%
df3=pd.DataFrame(columns=headings)
df3
# Out:
# Empty DataFrame
# Columns: [Sr. No., Date (dd/mm/yyyy), Startup Name, Industry / Vertical, Sub-Vertical, City / Location, Investors' Name, Investment Type, Amount (In USD)]
# Index: []

# %%
for row in table_3.find_all("tr")[1:]:
    data_3=row.find_all("td")
    row_data_3=[td.text.strip() for td in data_3]
    length= len(df3)
    df3.loc[length]=row_data_3

# %%
h2=soup.find_all("h2",class_="tablepress-table-name tablepress-table-name-id-50")
h2
# Out:
# [<h2 class="tablepress-table-name tablepress-table-name-id-50">September, 2020</h2>]

# %%
H2=[]
for i in h2:
    H2.append(i.text.replace("\n",""))
H2
# Out:
# ['September, 2020']

# %%
Month=pd.DataFrame({})
Month['MM/Yr']=H2
print(Month)
df3
# Out:
#              MM/Yr
# 0  September, 2020
#    Sr. No. Date (dd/mm/yyyy)     Startup Name  \
# 0        1        08/09/2020           Byju’s
# 1        2        12/09/2020        mCaffeine
# 2        3        09/09/2020           Qshala
# 3        4        02/09/2020            Winzo
# 4        5        09/09/2020      Hippo Video
# 5        6        07/09/2020          Melorra
# 6        7        07/09/2020              1mg
# 7        8        31/08/2020            mfine
# 8        9        31/08/2020             Apna
# 9       10        03/09/2020          Railofy
# 10      11        08/09/2020  Cell Propulsion
#
#                        Industry / Vertical  \
# 0                                  EduTech
# 1                            Personal Care
# 2                                  EduTech
# 3                            Online Gaming
# 4   Video Customer Experience(CX) Platform
# 5                               E-commerce
# 6                               E-commerce
# ...

# %%
frames = [df, df1, df3]

result = pd.concat(frames)
result
# Out:
#    Sr. No. Date (dd/mm/yyyy)               Startup Name  \
# 0        1        15/07/2020                   Flipkart
# 1        2        16/07/2020                    Vedantu
# 2        3        16/07/2020                       Crio
# 3        4        14/07/2020                    goDutch
# 4        5        13/07/2020                   Mystifly
# 5        6        09/07/2020               JetSynthesys
# 6        7        10/07/2020                   gigIndia
# 7        8        15/07/2020                  PumPumPum
# 8        9        14/07/2020                       FLYX
# 9       10        13/07/2020  Open Appliances Pvt. Ltd.
# 0        1        15/08/2020                     Practo
# 1        2        13/08/2020                    Medlife
# 2        3        13/08/2020                  HungerBox
# 3        4        04/08/2020                      Dunzo
# 4        5        11/08/2020                   Terra.do
# 5        6        12/08/2020                  Classplus
# ...

# %% [markdown]
# 7. Write a program to scrap all the available details of best gaming laptops from digit.in

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
url="https://www.digit.in/top-products/best-gaming-laptops-40.html"
page=requests.get(url)
soup=BeautifulSoup(page.text,'lxml')
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, user-scalable=1" name="viewport"/>
# <link href="https://www.digit.in/images/favicon.ico" rel="icon" type="image/x-icon"/>
# <link href="https://www.digit.in/css/top-10.css?v=302" rel="stylesheet" type="text/css"/>
# <link href="https://ajax.googleapis.com/" rel="preconnect"/>
# <link href="https://ajax.googleapis.com/" rel="dns-prefetch"/>
# <link href="https://www.gstatic.com/" rel="preconnect"/>
# <link href="https://www.gstatic.com/" rel="dns-prefetch"/>
# <link href="https://cdnjs.cloudflare.com/" rel="preconnect"/>
# <link href="https://ajax.googleapis.com/" rel="preconnect"/>
# <link href="https://ajax.googleapis.com/" rel="dns-prefetch"/>
# <link href="https://www.gstatic.com/" rel="preconnect"/>
# <link href="https://www.gstatic.com/" rel="dns-prefetch"/>
# <link href="https://cdnjs.cloudflare.com/" rel="preconnect"/>
# ...

# %%
containers=soup.find_all("div",{"class":"right-container"})
containers
# Out:
# [<div class="right-container">
#  <div class="TopNumbeHeading active sticky-footer" data-cat="Top_Ten_En_Scroll" data-eventaction="NonAMPScroll" data-index="1" data-lang="en" data-proname="1_Alienware Area 51M R2" data-title="Alienware Area 51M R2" id="toptenIdevent1">
#  <span>1.</span>
#  <a href="https://www.digit.in/laptops/alienware-area-51m-r2-price-228193.html">
#  <h3>ALIENWARE AREA 51M R2</h3>
#  </a>
#  </div>
#  <div class="Product-specs">
#  <div class="product-ickon" data-href="https://www.digit.in/laptops/alienware-area-51m-r2-price-228193.html">
#  <img alt="Alienware Area 51M R2" src="https://static.digit.in/product/thumb_184799_product_td_300.jpeg" title="Alienware Area 51M R2"/>
#  </div>
#  <div class="product-detail">
#  <div class="Specs-Wrap">
#  <ul>
#  <li>
#  <span><img alt="OS" data-src="https://static.digit.in/default/9d17abc8524c69c5d1a3b22d6b026eb7931e2d80.png" src="..."/> </span>
#  <div class="Wrap-pop">
#  OS
# ...

# %%
urls=container.find_all("h3")
urls
Title=[]
for i in urls:
       Title.append(i.text.replace("/h3",""))
Title
# Out:
# ['ALIENWARE AREA 51M R2',
#  'ALIENWARE M15 R3',
#  'ASUS ROG STRIX SCAR 15',
#  'ASUS ROG ZEPHYRUS G14',
#  'LENOVO LEGION 5I',
#  'ASUS ROG ZEPHYRUS DUO 15',
#  'ACER ASPIRE 7 GAMING']

# %%
df_name=pd.DataFrame({})
df_name['Titles']=Title
df_name
# Out:
#                      Titles
# 0     ALIENWARE AREA 51M R2
# 1          ALIENWARE M15 R3
# 2    ASUS ROG STRIX SCAR 15
# 3     ASUS ROG ZEPHYRUS G14
# 4          LENOVO LEGION 5I
# 5  ASUS ROG ZEPHYRUS DUO 15
# 6      ACER ASPIRE 7 GAMING

# %%
table_1 = soup.find_all("table")[2]
table_1

table_data = table_1.tbody.find_all("tr")
table_data
# Out:
# [<tr></tr>,
#  <tr><th colspan="3">SPECIFICATION</th></tr>,
#  <tr><td>OS</td> <td>:</td> <td>Windows 10 Home</td> </tr>,
#  <tr><td>Display</td> <td>:</td> <td>15.6" (3840 x 2160)</td> </tr>,
#  <tr><td>Processor</td> <td>:</td> <td>10th Generation Intel® Core™ i9-10980HK  | NA</td> </tr>,
#  <tr><td>Memory</td> <td>:</td> <td>1 TB SSD/16 GBGB DDR4</td> </tr>,
#  <tr> <td>Weight</td> <td>:</td> <td>NA</td> </tr>,
#  <tr> <td>Dimension</td> <td>:</td> <td>NA</td> </tr>,
#  <tr> <td>Graphics Processor</td> <td>:</td> <td>NA</td> </tr>,
#  <tr>
#  <td>Price</td>
#  <td>:</td>
#  <td>₹341,990</td>
#  </tr>]

# %%
for tr in table_data:
    tds = tr.findAll("td")
    if len(tds) < 1:
        continue
    name = tds[0].text
    print(name)
# Out:
# OS
# Display
# Processor
# Memory
# Weight
# Dimension
# Graphics Processor
# Price

# %%
for tr in table_data:
    tds = tr.findAll("td")                   
    if len(tds) < 1:
        continue
    name_data = tds[2].text
    print(name_data)
    
    value1=name_data
# Out:
# Windows 10 Home
# 15.6" (3840 x 2160)
# 10th Generation Intel® Core™ i9-10980HK  | NA
# 1 TB SSD/16 GBGB DDR4
# NA
# NA
# NA
# ₹341,990

# %%
import pandas as pd

df = pd.DataFrame(data)
df
# Out:
#                 OS              Display  \
# 0  Windows 10 Home  15.6" (3840 x 2160)
#
#                                        Processor                 Memory  \
# 0  10th Generation Intel® Core™ i9-10980HK  | NA  1 TB SSD/16 GBGB DDR4
#
#   Weight Dimension Graphics Processor     Price
# 0     NA        NA                 NA  ₹341,990

# %%
table_2 = soup.find_all("table")[3]
table_2
table_data_2 = table_2.tbody.find_all("tr")
table_data_2
# Out:
# [<tr></tr>,
#  <tr><th colspan="3">SPECIFICATION</th></tr>,
#  <tr><td>OS</td> <td>:</td> <td>Windows 10 Home</td> </tr>,
#  <tr><td>Display</td> <td>:</td> <td>15.6" (1920 x 1080)</td> </tr>,
#  <tr><td>Processor</td> <td>:</td> <td>AMD Ryzen™ 9 5900HX | 3.3 GHz</td> </tr>,
#  <tr><td>Memory</td> <td>:</td> <td>1 TB SSD/16 GBGB DDR4</td> </tr>,
#  <tr> <td>Weight</td> <td>:</td> <td>2.30</td> </tr>,
#  <tr> <td>Dimension</td> <td>:</td> <td>35.4 x 25.9 x 2.26</td> </tr>,
#  <tr> <td>Graphics Processor</td> <td>:</td> <td>NVIDIA® GeForce RTX™ 3070</td> </tr>]

# %%
for tr in table_data_2:
    tds = tr.findAll("td")
    if len(tds) < 1:
        continue
    name_data_2 = tds[2].text
    print(name_data_2)
# Out:
# Windows 10 Home
# 15.6" (1920 x 1080)
# AMD Ryzen™ 9 5900HX | 3.3 GHz
# 1 TB SSD/16 GBGB DDR4
# 2.30
# 35.4 x 25.9 x 2.26
# NVIDIA® GeForce RTX™ 3070

# %%
table_3 = soup.find_all("table")[4]
table_3
#table_data = table_1.tbody.find_all("tr")
#table2= table_1.find()
table_data_3 = table_3.tbody.find_all("tr")
table_data_3
# Out:
# [<tr></tr>,
#  <tr><th colspan="3">SPECIFICATION</th></tr>,
#  <tr><td>OS</td> <td>:</td> <td>Windows 10 Home</td> </tr>,
#  <tr><td>Display</td> <td>:</td> <td>14" (1920 x 1080)</td> </tr>,
#  <tr><td>Processor</td> <td>:</td> <td>AMD 3rd Generation Ryzen 9 | 3.3 GHz</td> </tr>,
#  <tr><td>Memory</td> <td>:</td> <td>1 TB SSD/16 GBGB DDR4</td> </tr>,
#  <tr> <td>Weight</td> <td>:</td> <td>1.65</td> </tr>,
#  <tr> <td>Dimension</td> <td>:</td> <td>32.5 x 22.1 x 1.8</td> </tr>,
#  <tr> <td>Graphics Processor</td> <td>:</td> <td>NVIDIA GeForce RTX 2060</td> </tr>]

# %%
for tr in table_data_3:
    tds = tr.findAll("td")
    if len(tds) < 1:
        continue
    name_data_3 = tds[2].text
    print(name_data_3)
# Out:
# Windows 10 Home
# 14" (1920 x 1080)
# AMD 3rd Generation Ryzen 9 | 3.3 GHz
# 1 TB SSD/16 GBGB DDR4
# 1.65
# 32.5 x 22.1 x 1.8
# NVIDIA GeForce RTX 2060

# %%
table_4 = soup.find_all("table")[6]
table_4
#table_data = table_1.tbody.find_all("tr")
#table2= table_1.find()
table_data_4 = table_4.tbody.find_all("tr")
table_data_4
# Out:
# [<tr></tr>,
#  <tr><th colspan="3">SPECIFICATION</th></tr>,
#  <tr><td>OS</td> <td>:</td> <td>Windows 10 Pro</td> </tr>,
#  <tr><td>Display</td> <td>:</td> <td>15.6" (1920 x 1080)</td> </tr>,
#  <tr><td>Processor</td> <td>:</td> <td>10th Generation Intel® Core™ i5-10300H | 2.50 GHz</td> </tr>,
#  <tr><td>Memory</td> <td>:</td> <td>1 TB SSD/16 GBGB DDR4</td> </tr>,
#  <tr> <td>Weight</td> <td>:</td> <td>2.3</td> </tr>,
#  <tr> <td>Dimension</td> <td>:</td> <td>363.06 x 259.61 x 23.57</td> </tr>,
#  <tr> <td>Graphics Processor</td> <td>:</td> <td>NVIDIA® GeForce® GTX 1650 4GB</td> </tr>]

# %%
for tr in table_data_4:
    tds = tr.findAll("td")
    if len(tds) < 1:
        continue
    name_data_4 = tds[2].text
    print(name_data_4)
# Out:
# Windows 10 Pro
# 15.6" (1920 x 1080)
# 10th Generation Intel® Core™ i5-10300H | 2.50 GHz
# 1 TB SSD/16 GBGB DDR4
# 2.3
# 363.06 x 259.61 x 23.57
# NVIDIA® GeForce® GTX 1650 4GB

# %%
table_5 = soup.find_all("table")[8]
table_5
#table_data = table_1.tbody.find_all("tr")
#table2= table_1.find()
table_data_5 = table_5.tbody.find_all("tr")
table_data_5
# Out:
# [<tr></tr>,
#  <tr><th colspan="3">SPECIFICATION</th></tr>,
#  <tr><td>OS</td> <td>:</td> <td>Windows 10</td> </tr>,
#  <tr><td>Display</td> <td>:</td> <td>15.6" (3840 x 1100)</td> </tr>,
#  <tr><td>Processor</td> <td>:</td> <td>Intel Core i7 10th Gen 10875H  | NA</td> </tr>,
#  <tr><td>Memory</td> <td>:</td> <td>512 GB SSD/4 GBGB DDR4</td> </tr>,
#  <tr> <td>Weight</td> <td>:</td> <td>2.4</td> </tr>,
#  <tr> <td>Dimension</td> <td>:</td> <td>268.30 x 360.00 x 20.90</td> </tr>,
#  <tr> <td>Graphics Processor</td> <td>:</td> <td>NVIDIA GeForce RTX 2070 Max-Q</td> </tr>]

# %%
for tr in table_data_5:
    tds = tr.findAll("td")
    if len(tds) < 1:
        continue
    name_data_5 = tds[2].text
    print(name_data_5)
# Out:
# Windows 10
# 15.6" (3840 x 1100)
# Intel Core i7 10th Gen 10875H  | NA
# 512 GB SSD/4 GBGB DDR4
# 2.4
# 268.30 x 360.00 x 20.90
# NVIDIA GeForce RTX 2070 Max-Q

# %%
table_6 = soup.find_all("table")[10]
table_6
#table_data = table_1.tbody.find_all("tr")
#table2= table_1.find()
table_data_6 = table_6.tbody.find_all("tr")
table_data_6
# Out:
# [<tr></tr>,
#  <tr><th colspan="3">SPECIFICATION</th></tr>,
#  <tr><td>OS</td> <td>:</td> <td>Windows 10 Home</td> </tr>,
#  <tr><td>Display</td> <td>:</td> <td>15.6" (1920 x 1080)</td> </tr>,
#  <tr><td>Processor</td> <td>:</td> <td>AMD Ryzen™ 5-5500U hexa-core  | NA</td> </tr>,
#  <tr><td>Memory</td> <td>:</td> <td>512 GB SSD/8 GBGB DDR4</td> </tr>,
#  <tr> <td>Weight</td> <td>:</td> <td>2.15</td> </tr>,
#  <tr> <td>Dimension</td> <td>:</td> <td>2.29 x 36.3 x 25.4</td> </tr>,
#  <tr> <td>Graphics Processor</td> <td>:</td> <td>NVIDIA® GeForce® GTX 1650</td> </tr>]

# %%
for tr in table_data_6:
    tds = tr.findAll("td")
    if len(tds) < 1:
        continue
    name_data_6 = tds[2].text
    print(name_data_6)
# Out:
# Windows 10 Home
# 15.6" (1920 x 1080)
# AMD Ryzen™ 5-5500U hexa-core  | NA
# 512 GB SSD/8 GBGB DDR4
# 2.15
# 2.29 x 36.3 x 25.4
# NVIDIA® GeForce® GTX 1650

# %%
import pandas as pd

data = {'OS':  ['Windows 10 Home', 'Windows 10 Home','Windows 10 Home','Windows 10 Pro','Windows 10 Pro','Windows 10','Windows 10 Home'],
        'Display': ['15.6" (3840 x 2160)', '15.6" (1920 x 1080)','14" (1920 x 1080)','15.6" (1920 x 1080)','15.6" (1920 x 1080)','15.6" (3840 x 1100)',
                    '15.6" (1920 x 1080)'],
        'Processor':['10th Generation Intel® Core™ i9-10980HK  | NA','AMD Ryzen™ 9 5900HX | 3.3 GHz','AMD 3rd Generation Ryzen 9 | 3.3 GHz','10th Generation Intel® Core™ i5-10300H | 2.50 GHz','10th Generation Intel® Core™ i5-10300H | 2.50 GHz',
                     'Intel Core i7 10th Gen 10875H  | NA','AMD Ryzen™ 5-5500U hexa-core  | NA'],
        'Memory':['1 TB SSD/16 GBGB DDR4','1 TB SSD/16 GBGB DDR4','1 TB SSD/16 GBGB DDR4','1 TB SSD/16 GBGB DDR4','1 TB SSD/16 GBGB DDR4','1 TB SSD/16 GBGB DDR4',
                  '512 GB SSD/4 GBGB DDR4'],
        'Weight':['NA','2.30','1.65','2.3','2.3','2.4','2.15'],
        'Dimension':['NA','35.4 x 25.9 x 2.26','32.5 x 22.1 x 1.8','363.06 x 259.61 x 23.57','363.06 x 259.61 x 23.57',
                     '268.30 x 360.00 x 20.90','2.29 x 36.3 x 25.4'],
        'Graphic Processor':['NA','NVIDIA® GeForce RTX™ 3070','NVIDIA GeForce RTX 2060','NVIDIA® GeForce® GTX 1650 4GB','NVIDIA® GeForce® GTX 1650 4GB','NVIDIA GeForce RTX 2070 Max-Q',
                             'NVIDIA® GeForce® GTX 1650'],
        'Price':['₹341,990','NA','NA','NA','NA','NA','NA']
    
        }

df = pd.DataFrame(data)
df
dataframe=
# Out:
#                 OS              Display  \
# 0  Windows 10 Home  15.6" (3840 x 2160)
# 1  Windows 10 Home  15.6" (1920 x 1080)
# 2  Windows 10 Home    14" (1920 x 1080)
# 3   Windows 10 Pro  15.6" (1920 x 1080)
# 4   Windows 10 Pro  15.6" (1920 x 1080)
# 5       Windows 10  15.6" (3840 x 1100)
# 6  Windows 10 Home  15.6" (1920 x 1080)
#
#                                            Processor                  Memory  \
# 0      10th Generation Intel® Core™ i9-10980HK  | NA   1 TB SSD/16 GBGB DDR4
# 1                      AMD Ryzen™ 9 5900HX | 3.3 GHz   1 TB SSD/16 GBGB DDR4
# 2               AMD 3rd Generation Ryzen 9 | 3.3 GHz   1 TB SSD/16 GBGB DDR4
# 3  10th Generation Intel® Core™ i5-10300H | 2.50 GHz   1 TB SSD/16 GBGB DDR4
# 4  10th Generation Intel® Core™ i5-10300H | 2.50 GHz   1 TB SSD/16 GBGB DDR4
# 5                Intel Core i7 10th Gen 10875H  | NA   1 TB SSD/16 GBGB DDR4
# 6                 AMD Ryzen™ 5-5500U hexa-core  | NA  512 GB SSD/4 GBGB DDR4
#
# ...

# %%
import pandas as pd

# %%
import selenium
import pandas as pd  
from selenium import webdriver
from time import sleep
import time

# %%
driver = webdriver.Chrome(r"C:\Users\IFATH FATIMA\Downloads\chromedriver_win32 (6)\chromedriver")
url='https://www.digit.in/top-products/best-gaming-laptops-40.html'
driver.get(url)
# Out:
# <ipython-input-1057-9d60cb4a1154>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r"C:\Users\IFATH FATIMA\Downloads\chromedriver_win32 (6)\chromedriver")

# %%
full_specs=[]

urls=driver.find_elements_by_xpath("//div[@class='full-specs']/span")#getting the url of full specs links

for i in urls:

    if i.get_attribute('data-href'):

        full_specs.append(i.get_attribute('data-href'))
# Out:
# C:\Users\IFATH FATIMA\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:502: UserWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   warnings.warn("find_elements_by_* commands are deprecated. Please use find_elements() instead")

# %%
full_specs
# Out:
# []

# %%
title=driver.find_elements_by_xpath('//div[@class="TopNumbeHeading active sticky-footer"]')
title
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="02ff5051f33a27b601e643062954b9dd", element="508f84a1-5680-4ccb-a8a9-5d61ffac0b0f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="02ff5051f33a27b601e643062954b9dd", element="26429204-a6c4-4dbd-ae77-e9f7197b8dda")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="02ff5051f33a27b601e643062954b9dd", element="c3370ba9-33af-4952-afb9-4e242c174402")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="02ff5051f33a27b601e643062954b9dd", element="530eb473-ecfe-4fb2-bac0-da8350b8332b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="02ff5051f33a27b601e643062954b9dd", element="55093eff-72ee-45a4-bc48-6567cce803d9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="02ff5051f33a27b601e643062954b9dd", element="3c430ed1-fee8-44ac-bc7d-85112af41c2a")>,
# ...

# %%
Title=[]
for i in title:
    Title.append(i.text.replace("\n",""))
Title
# Out:
# ['1.ALIENWARE AREA 51M R2',
#  '2.ALIENWARE M15 R3',
#  '3.ASUS ROG STRIX SCAR 15',
#  '4.ASUS ROG ZEPHYRUS G14',
#  '5.LENOVO LEGION 5I',
#  '6.ASUS ROG ZEPHYRUS DUO 15',
#  '7.ACER ASPIRE 7 GAMING']
